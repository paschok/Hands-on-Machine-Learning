# %% [markdown]
# ## K-Means

# %% [markdown]
# #### generating some blobs

# %%
import numpy as np

blob_centers = np.array(
    [[ 0.2,  2.3],
     [-1.5 ,  2.3],
     [-2.8,  1.8],
     [-2.8,  2.8],
     [-2.8,  1.3]])
blob_std = np.array([0.4, 0.3, 0.1, 0.1, 0.1])

# %%
from sklearn.datasets import make_blobs

X, y = make_blobs(n_samples=2000, centers=blob_centers,
                  cluster_std=blob_std, random_state=42)

X.shape
# Out:
# (2000, 2)

# %%
y.shape
# Out:
# (2000,)

# %% [markdown]
# #### Plotting blobs

# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
def plot_clusters(X, y=None):
    plt.scatter(X[:, 0], X[:, 1], c=y, s=1)
    plt.xlabel("$x_1$", fontsize=14)
    plt.ylabel("$x_2$", fontsize=14, rotation=0)
    
    
plt.figure(figsize=(16, 10))
plot_clusters(X)
plt.show()

# %% [markdown]
# #### Let's train a K-Means clusterer on this dataset. It will try to find each blob's center and assign each instance to the closest blob:

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=5, random_state=42)
y_pred = kmeans.fit_predict(X)

# %% [markdown]
# #### Each instance was assigned to one of the 5 clusters:
# The KMeans instance preserves a copy of the labels of the instances it was trained on, available via the labels_ instance variable:

# %%
y_pred
# Out:
# array([2, 1, 3, ..., 1, 2, 4], dtype=int32)

# %%
y_pred is kmeans.labels_
# Out:
# True

# %%
kmeans.labels_.shape
# Out:
# (2000,)

# %% [markdown]
# #### The five centroids that the algorithm found:

# %%
kmeans.cluster_centers_
# Out:
# array([[-2.79244799,  1.2973862 ],
#        [ 0.20925539,  2.30351618],
#        [-2.79846237,  2.80004584],
#        [-1.4453407 ,  2.32051326],
#        [-2.80372723,  1.80873739]])

# %%
#### Assigning new instances to the cluster whose centroid is closest:

# %%
X_new = np.array([[0, 2], [3, 2], [-3, 3], [-3, 2.5]])

kmeans.predict(X_new)
# Out:
# array([1, 1, 2, 2], dtype=int32)

# %% [markdown]
# #### In the KMeans class, the transform() method measures the distance from each instance to every centroid:
#
# In this example, the first instance in X_new is located at a distance of 2.87 from the first centroid, 0.36 from the second centroid, 2.91 from the third centroid, 1.48 from the fourth centroid, and 2.81 from the fifth centroid
# ### woth noting!
# .. if we have a high-dimensional dataset and you transform it this way, you end up with a k- dimensional dataset: this transformation can be a very efficient nonlinear dimensionality reduction technique.

# %%
kmeans.transform(X_new)
# Out:
# array([[2.87948466, 0.36865958, 2.91057812, 1.48045212, 2.81024337],
#        [5.8349053 , 2.80720102, 5.85339553, 4.45688037, 5.80687792],
#        [1.71521765, 3.28396253, 0.28389977, 1.69666372, 1.20732332],
#        [1.22039247, 3.21526454, 0.36144837, 1.56498595, 0.7185868 ]])

# %% [markdown]
# #### Centroid Initialization method
#
# If you happen to know approximately where the centroids should be (e.g., if you ran another clustering algorithm earlier), then you can set the init hyperparameter to a NumPy array containing the list of centroids, and set n_init to 1:
# <code>
# good_init = np.array([[-3, 3], [-3, 2], [-3, 1], [-1, 2], [0, 2]])
#
# kmeans = KMeans(n_clusters=5, init=good_init, n_init=1)
#
# </code>
#
# The number of random initializations is controlled by the n_init hyperparameter: by default, it is equal to 10, which means that the whole algorithm described earlier runs 10 times when you call fit(), and Scikit-Learn keeps the best solution by using performance metric! That metric is called the model’s inertia, which is the mean squared distance between each instance and its closest centroid.
#
# The KMeans class runs the algorithm n_init times and keeps the model with the lowest inertia.

# %%
kmeans.inertia_
# Out:
# 213.4217713125891

# %% [markdown]
# The score() method returns the negative inertia.

# %%
kmeans.score(X)
# Out:
# -213.42177131258978

# %% [markdown]
# ### The KMeans class uses this initialization method of K-Means++.

# %% [markdown]
# ### Mini-batch K-Means

# %%
from sklearn.cluster import MiniBatchKMeans 

minibatch_kmeans = MiniBatchKMeans(n_clusters=5)
minibatch_kmeans.fit(X)
# Out:
# MiniBatchKMeans(batch_size=100, compute_labels=True, init='k-means++',
#                 init_size=None, max_iter=100, max_no_improvement=10,
#                 n_clusters=5, n_init=3, random_state=None,
#                 reassignment_ratio=0.01, tol=0.0, verbose=0)
